# %% [markdown]
# <a href="https://colab.research.google.com/github/cyphr0st/infosec/blob/analytics/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/cyphr0st/infosec/master/data2/drinks.csv')
pd.set_option('max_rows', 99999)
type(drinks)
# Out:
# pandas.core.frame.DataFrame

# %%
drinks
# Out:
#          country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0    Afghanistan              0  ...                           0.0         AS
# 1        Albania             89  ...                           4.9         EU
# 2        Algeria             25  ...                           0.7         AF
# 3        Andorra            245  ...                          12.4         EU
# 4         Angola            217  ...                           5.9         AF
# ..           ...            ...  ...                           ...        ...
# 188    Venezuela            333  ...                           7.7         SA
# 189      Vietnam            111  ...                           2.0         AS
# 190        Yemen              6  ...                           0.1         AS
# 191       Zambia             32  ...                           2.5         AF
# 192     Zimbabwe             64  ...                           4.7         AF
#
# [193 rows x 6 columns]

# %%
drinks.head
# Out:
# <bound method NDFrame.head of          country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0    Afghanistan              0  ...                           0.0         AS
# 1        Albania             89  ...                           4.9         EU
# 2        Algeria             25  ...                           0.7         AF
# 3        Andorra            245  ...                          12.4         EU
# 4         Angola            217  ...                           5.9         AF
# ..           ...            ...  ...                           ...        ...
# 188    Venezuela            333  ...                           7.7         SA
# 189      Vietnam            111  ...                           2.0         AS
# 190        Yemen              6  ...                           0.1         AS
# 191       Zambia             32  ...                           2.5         AF
# 192     Zimbabwe             64  ...                           4.7         AF
#
# ...

# %%
drinks.tail
# Out:
# <bound method NDFrame.tail of          country  beer_servings  ...  total_litres_of_pure_alcohol  continent
# 0    Afghanistan              0  ...                           0.0         AS
# 1        Albania             89  ...                           4.9         EU
# 2        Algeria             25  ...                           0.7         AF
# 3        Andorra            245  ...                          12.4         EU
# 4         Angola            217  ...                           5.9         AF
# ..           ...            ...  ...                           ...        ...
# 188    Venezuela            333  ...                           7.7         SA
# 189      Vietnam            111  ...                           2.0         AS
# 190        Yemen              6  ...                           0.1         AS
# 191       Zambia             32  ...                           2.5         AF
# 192     Zimbabwe             64  ...                           4.7         AF
#
# ...

# %%
drinks.describe()
# Out:
#        beer_servings  ...  total_litres_of_pure_alcohol
# count     193.000000  ...                    193.000000
# mean      106.160622  ...                      4.717098
# std       101.143103  ...                      3.773298
# min         0.000000  ...                      0.000000
# 25%        20.000000  ...                      1.300000
# 50%        76.000000  ...                      4.200000
# 75%       188.000000  ...                      7.200000
# max       376.000000  ...                     14.400000
#
# [8 rows x 4 columns]

# %%
drinks.co
lumns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
d = {'a':[1,2], 'b':[3,4]}
pd.DataFrame(d)
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks[drinks['continent'].isnull()]
# Out:
#                           country  ...  continent
# 5               Antigua & Barbuda  ...        NaN
# 11                        Bahamas  ...        NaN
# 14                       Barbados  ...        NaN
# 17                         Belize  ...        NaN
# 32                         Canada  ...        NaN
# 41                     Costa Rica  ...        NaN
# 43                           Cuba  ...        NaN
# 50                       Dominica  ...        NaN
# 51             Dominican Republic  ...        NaN
# 54                    El Salvador  ...        NaN
# 68                        Grenada  ...        NaN
# 69                      Guatemala  ...        NaN
# 73                          Haiti  ...        NaN
# 74                       Honduras  ...        NaN
# 84                        Jamaica  ...        NaN
# 109                        Mexico  ...        NaN
# 122                     Nicaragua  ...        NaN
# 130                        Panama  ...        NaN
# ...

# %%
drinks.fillna(value='NA')
# Out:
#                           country  ...  continent
# 0                     Afghanistan  ...         AS
# 1                         Albania  ...         EU
# 2                         Algeria  ...         AF
# 3                         Andorra  ...         EU
# 4                          Angola  ...         AF
# 5               Antigua & Barbuda  ...         NA
# 6                       Argentina  ...         SA
# 7                         Armenia  ...         EU
# 8                       Australia  ...         OC
# 9                         Austria  ...         EU
# 10                     Azerbaijan  ...         EU
# 11                        Bahamas  ...         NA
# 12                        Bahrain  ...         AS
# 13                     Bangladesh  ...         AS
# 14                       Barbados  ...         NA
# 15                        Belarus  ...         EU
# 16                        Belgium  ...         EU
# 17                         Belize  ...         NA
# ...

# %%
drinks.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
drinks['continent']
# Out:
# 0       AS
# 1       EU
# 2       AF
# 3       EU
# 4       AF
# 5      NaN
# 6       SA
# 7       EU
# 8       OC
# 9       EU
# 10      EU
# 11     NaN
# 12      AS
# 13      AS
# 14     NaN
# 15      EU
# 16      EU
# 17     NaN
# 18      AF
# 19      AS
# 20      SA
# 21      EU
# 22      AF
# 23      SA
# 24      AS
# 25      EU
# 26      AF
# 27      AF
# 28      AF
# 29      AF
# 30      AS
# 31      AF
# 32     NaN
# 33      AF
# 34      AF
# 35      SA
# 36      AS
# 37      SA
# 38      AF
# 39      AF
# 40      OC
# 41     NaN
# 42      EU
# 43     NaN
# 44      EU
# 45      EU
# 46      AS
# 47      AF
# 48      EU
# 49      AF
# 50     NaN
# 51     NaN
# 52      SA
# 53      AF
# 54     NaN
# 55      AF
# 56      AF
# 57      EU
# 58      AF
# 59      OC
# 60      EU
# 61      EU
# 62      AF
# 63      AF
# 64      EU
# 65      EU
# 66      AF
# 67      EU
# 68     NaN
# 69     NaN
# 70      AF
# 71      AF
# 72      SA
# 73     NaN
# 74     NaN
# 75      EU
# ...
